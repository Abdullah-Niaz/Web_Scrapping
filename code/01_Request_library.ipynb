# %%
import requests

# %%
url = "https://www.thetimes.co.uk/"
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="en" class="no-js has-flex"><head><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="google-site-verification" content="wgOLxykhpsfs3Xzr-122VxguqHHRcfHDzAod4gQaIm8" /><title>The Times &amp; The Sunday Times: breaking news &amp; today\'s latest headlines</title><meta name="description" content="The latest UK and world news, business, sport and comment from The Times and The Sunday Time"/><meta property="og:title" content="The Times &amp; The Sunday Times" /><meta property="og:type" content="website" /><meta property="og:url" content="https://www.thetimes.co.uk" /><meta property="og:description" content="News and opinion from The Times &amp; The Sunday Times" /><meta property="fb:app_id" content="734957826605763"/><meta name="twitter:title" content="The Times &amp; The Sunday Times" /><meta name="twitter:card" content="summary" /><meta name="twitter:url" co
# ...

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='nuk_customer_location_hint', value='GLOBAL', port=None, port_specified=False, domain='.thetimes.co.uk', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='nuk_customer_country_code', value='PK', port=None, port_specified=False, domain='.thetimes.co.uk', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='nuk_ni_statuscode', value='acsaz-307', port=None, port_specified=False, domain='www.thetimes.co.uk', domain_specified=False, domain_initial_dot=False, path='/', path_specified=False, secure=False, expires=1696822842, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]>
